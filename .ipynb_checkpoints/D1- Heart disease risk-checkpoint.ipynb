# %% [markdown]
# # Basic Pandas

# %% [markdown]
# **Edited by Sara Masoud**

# %%
# import the library
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('Data/heart_risk.csv')
df
# Out:
#       Patient_ID  age   bmi  systolic_bp  diastolic_bp  cholesterol_mg_dl  \
# 0              1   62  25.0          142            93                247
# 1              2   54  29.7          158           101                254
# 2              3   46  36.2          170           113                276
# 3              4   48  30.4          153            98                230
# 4              5   46  25.3          139            87                206
# ...          ...  ...   ...          ...           ...                ...
# 5495        5496   19  26.0          121            75                185
# 5496        5497   18  30.9          128            82                235
# 5497        5498   63  29.5          142            92                239
# 5498        5499   46  27.5          138            91                237
# 5499        5500   79  29.0          157           102                265
#
#       resting_heart_rate smoking_status  daily_steps  stress_level  \
# ...

# %%
#rename the cloumns
df = df.rename(columns={
    'Patient_ID': 'PatientID',
    'age': 'Age',
    'bmi': 'Bmi',
    'systolic_bp': 'systolicBp',
    'diastolic_bp': 'diastolicBp',
    'cholesterol_mg_dl': 'cholesterolMgDl',
    'resting_heart_rate': 'restingHeartRate',
    'smoking_status': 'smokingStatus',
    'daily_steps': 'dailySteps',
    'stress_level': 'stressLevel',
    'physical_activity_hours_per_week': 'physicalActivityHoursPerWeek',
    'sleep_hours': 'sleepHours',
    'family_history_heart_disease': 'familyHistoryHeartDisease',
    'diet_quality_score': 'dietQualityScore',
    'alcohol_units_per_week': 'alcoholUnitsPerWeek',
    'heart_disease_risk_score': 'heartDiseaseRiskScore',
    'risk_category': 'riskCategory'
})

# %%
df.head()
# Out:
#    PatientID  Age   Bmi  systolicBp  diastolicBp  cholesterolMgDl  \
# 0          1   62  25.0         142           93              247
# 1          2   54  29.7         158          101              254
# 2          3   46  36.2         170          113              276
# 3          4   48  30.4         153           98              230
# 4          5   46  25.3         139           87              206
#
#    restingHeartRate smokingStatus  dailySteps  stressLevel  \
# 0                72         Never       11565            3
# 1                74       Current        4036            8
# 2                80       Current        3043            9
# 3                73        Former        5604            5
# 4                69       Current        7464            1
#
#    physicalActivityHoursPerWeek  sleepHours familyHistoryHeartDisease  \
# 0                           5.6         8.2                        No
# ...

# %%
# we only want to check patientid their age and there heart disease risk score
df[['PatientID','Age','heartDiseaseRiskScore','riskCategory']]
# Out:
#       PatientID  Age  heartDiseaseRiskScore riskCategory
# 0             1   62                   28.1       Medium
# 1             2   54                   63.0         High
# 2             3   46                   73.1         High
# 3             4   48                   39.5       Medium
# 4             5   46                   29.3       Medium
# ...         ...  ...                    ...          ...
# 5495       5496   19                    0.0          Low
# 5496       5497   18                   16.8          Low
# 5497       5498   63                   31.8       Medium
# 5498       5499   46                   29.4       Medium
# 5499       5500   79                   50.9       Medium
#
# [5500 rows x 4 columns]

# %%
#sort the values from ascending to descending
df = df.sort_values(by=['PatientID', 'Age', 'heartDiseaseRiskScore'], ascending=True)
df
# Out:
#       PatientID  Age   Bmi  systolicBp  diastolicBp  cholesterolMgDl  \
# 0             1   62  25.0         142           93              247
# 1             2   54  29.7         158          101              254
# 2             3   46  36.2         170          113              276
# 3             4   48  30.4         153           98              230
# 4             5   46  25.3         139           87              206
# ...         ...  ...   ...         ...          ...              ...
# 5495       5496   19  26.0         121           75              185
# 5496       5497   18  30.9         128           82              235
# 5497       5498   63  29.5         142           92              239
# 5498       5499   46  27.5         138           91              237
# 5499       5500   79  29.0         157          102              265
#
#       restingHeartRate smokingStatus  dailySteps  stressLevel  \
# 0                   72         Never       11565            3
# ...

# %%
#WEEK3

# %%
# find the average of each column
df.mean(numeric_only=True)
# Out:
# PatientID                       2750.500000
# Age                               53.872000
# Bmi                               28.170818
# systolicBp                       147.248182
# diastolicBp                       95.756727
# cholesterolMgDl                  239.684182
# restingHeartRate                  74.075091
# dailySteps                      5902.929455
# stressLevel                        4.907091
# physicalActivityHoursPerWeek       3.299364
# sleepHours                         6.869364
# dietQualityScore                   5.162909
# alcoholUnitsPerWeek                3.782200
# heartDiseaseRiskScore             37.540455
# dtype: float64

# %%
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values
print(X)
# Out:
# [[1 62 25.0 ... 7 0.7 28.1]
#  [2 54 29.7 ... 5 4.5 63.0]
#  [3 46 36.2 ... 1 20.8 73.1]
#  ...
#  [5498 63 29.5 ... 6 2.4 31.8]
#  [5499 46 27.5 ... 5 2.3 29.4]
#  [5500 79 29.0 ... 5 6.3 50.9]]

# %%
print(y)
# Out:
# ['Medium' 'High' 'High' ... 'Medium' 'Medium' 'Medium']

# %%
df.head()
# Out:
#    PatientID  Age   Bmi  systolicBp  diastolicBp  cholesterolMgDl  \
# 0          1   62  25.0         142           93              247
# 1          2   54  29.7         158          101              254
# 2          3   46  36.2         170          113              276
# 3          4   48  30.4         153           98              230
# 4          5   46  25.3         139           87              206
#
#    restingHeartRate smokingStatus  dailySteps  stressLevel  \
# 0                72         Never       11565            3
# 1                74       Current        4036            8
# 2                80       Current        3043            9
# 3                73        Former        5604            5
# 4                69       Current        7464            1
#
#    physicalActivityHoursPerWeek  sleepHours familyHistoryHeartDisease  \
# 0                           5.6         8.2                        No
# ...

# %%
#WEEK4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5500 entries, 0 to 5499
# Data columns (total 17 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   PatientID                     5500 non-null   int64
#  1   Age                           5500 non-null   int64
#  2   Bmi                           5500 non-null   float64
#  3   systolicBp                    5500 non-null   int64
#  4   diastolicBp                   5500 non-null   int64
#  5   cholesterolMgDl               5500 non-null   int64
#  6   restingHeartRate              5500 non-null   int64
#  7   smokingStatus                 5500 non-null   object
#  8   dailySteps                    5500 non-null   int64
#  9   stressLevel                   5500 non-null   int64
#  10  physicalActivityHoursPerWeek  5500 non-null   float64
#  11  sleepHours                    5500 non-null   float64
# ...

# %%
df.describe()
# Out:
#          PatientID          Age          Bmi   systolicBp  diastolicBp  \
# count  5500.000000  5500.000000  5500.000000  5500.000000  5500.000000
# mean   2750.500000    53.872000    28.170818   147.248182    95.756727
# std    1587.857571    21.196017     4.189877    13.222701     9.451559
# min       1.000000    18.000000    15.000000   108.000000    64.000000
# 25%    1375.750000    36.000000    25.200000   138.000000    89.000000
# 50%    2750.500000    54.000000    28.400000   147.000000    96.000000
# 75%    4125.250000    72.000000    31.100000   156.000000   102.000000
# max    5500.000000    90.000000    40.900000   192.000000   120.000000
#
#        cholesterolMgDl  restingHeartRate    dailySteps  stressLevel  \
# count      5500.000000       5500.000000   5500.000000  5500.000000
# mean        239.684182         74.075091   5902.929455     4.907091
# std          28.570177          6.392166   3041.084590     2.298173
# ...

# %%
def descriptive_stats(sample, field):
    return sample[field].describe()

# %%
descriptive_stats(df,'heartDiseaseRiskScore')
# Out:
# count    5500.000000
# mean       37.540455
# std        24.287026
# min         0.000000
# 25%        18.400000
# 50%        36.700000
# 75%        55.500000
# max       100.000000
# Name: heartDiseaseRiskScore, dtype: float64

# %%
random_sample = df.sample(n=150)
descriptive_stats(random_sample,'heartDiseaseRiskScore')
# Out:
# count    150.000000
# mean      37.080667
# std       23.225711
# min        0.000000
# 25%       19.650000
# 50%       39.200000
# 75%       52.975000
# max       88.400000
# Name: heartDiseaseRiskScore, dtype: float64

# %%
systematic_sample = df.iloc[::10]

descriptive_stats(systematic_sample,'heartDiseaseRiskScore')
# Out:
# count    550.000000
# mean      36.760545
# std       24.418241
# min        0.000000
# 25%       15.575000
# 50%       37.100000
# 75%       54.425000
# max       96.500000
# Name: heartDiseaseRiskScore, dtype: float64

# %%
plt.figure()
plt.hist(df['heartDiseaseRiskScore'], bins=10, edgecolor='black')
plt.title("Histogram")
plt.xlabel("Risk Score")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure()
plt.boxplot(df['heartDiseaseRiskScore'], vert=False)
plt.title("Box Plot")
plt.xlabel("Risk Score")
plt.show()

# %%
df.plot.scatter(x='Bmi', y='heartDiseaseRiskScore', s=2, c='red');

# %%
#pivot table counting cholestrol & smoking status

# pivot table
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

pivot_table = pd.pivot_table(
    df,
    values='cholesterolMgDl',
    index='smokingStatus',
    aggfunc='mean'
)

plt.figure(figsize=(8,6))
sns.heatmap(
    pivot_table,
    cmap='Reds',
    annot=True,
    fmt=".1f",
    linewidths=0.5
)

plt.ylabel('Smoking Status')
plt.xlabel('Cholesterol (mg/dL)')
plt.title('Average Cholesterol by Smoking Status')

plt.show()

# %%
df.corr(method='spearman', numeric_only=True)
# Out:
#                               PatientID       Age       Bmi  systolicBp  \
# PatientID                      1.000000 -0.028400 -0.006068   -0.024731
# Age                           -0.028400  1.000000  0.234390    0.724880
# Bmi                           -0.006068  0.234390  1.000000    0.591322
# systolicBp                    -0.024731  0.724880  0.591322    1.000000
# diastolicBp                   -0.026484  0.654099  0.532077    0.902701
# cholesterolMgDl               -0.015808  0.659860  0.755040    0.762350
# restingHeartRate               0.022209 -0.002027  0.490463    0.348181
# dailySteps                    -0.012704 -0.010732 -0.615989   -0.366448
# stressLevel                   -0.000403 -0.002266  0.315783    0.401869
# physicalActivityHoursPerWeek  -0.016534 -0.001384 -0.648680   -0.369504
# sleepHours                     0.004152 -0.005610 -0.071896   -0.094345
# dietQualityScore              -0.002252  0.011253 -0.821949   -0.379672
# ...

# %%
#week5

# %%
#Check for normality
from scipy.stats import shapiro

# select the column you want to test
risk = df['heartDiseaseRiskScore']

# Shapiro-Wilk test
stat, p = shapiro(risk)

print('stat=%.2f, p=%.30f' % (stat, p))

if p > 0.05:
    print('Normal distribution')
else:
    print('Not a normal distribution')
# Out:
# stat=0.97, p=0.000000000000000000000000000000
# Not a normal distribution
# C:\Users\HP\anaconda3\Lib\site-packages\scipy\stats\_axis_nan_policy.py:579: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 5500.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
# Perform Pearson's Correlation
from scipy.stats import pearsonr

r, p_value = pearsonr(df['Age'], df['heartDiseaseRiskScore'])

print(f"Pearson's Correlation Coefficient: {r:.4f}")
print(f"P_Value: {p_value:.4f}")
# Out:
# Pearson's Correlation Coefficient: 0.6943
# P_Value: 0.0000

# %%
#chi square testing
from scipy.stats import chi2_contingency

# create a contingency table
contingency_data = pd.crosstab(df['smokingStatus'], df['riskCategory'])

# chi-square test
chi2, p, dof, expected = chi2_contingency(contingency_data)

print('chi2=%.3f, p=%.3f' % (chi2, p))

if p > 0.05:
    print('independent categories')
else:
    print('dependent categories')
# Out:
# chi2=839.983, p=0.000
# dependent categories
